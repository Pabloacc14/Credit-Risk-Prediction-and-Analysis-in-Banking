# %% [markdown]
# # Exploratory Data Analysis (EDA)
#
# ## Objective
# The goal of this notebook is to explore and understand the dataset, identify patterns related to loan default, and generate initial insights that will guide feature engineering and model selection.
#
# ## Key Questions
# - How is the target variable distributed?
# - What financial characteristics are associated with higher default risk?
# - Are there strong correlations between variables?
# - Are there data quality issues such as missing values or outliers?
#
# ## Steps
# 1. Data loading
# 2. Data overview
# 3. Missing values analysis
# 4. Univariate analysis
# 5. Bivariate analysis
# 6. Initial insights
